# %% [markdown]
# # 10 Academy: Artificial Intelligence Mastery

# %% [markdown]
# ## Project: Change point analysis and statistical modelling of time series data - detecting changes and associating causes on time series data

# %% [markdown]
# ### Data Analysis Workflow
# #### Ethel.C

# %%
import sys
import pandas as pd

scripts_dir = r'E:\DS+ML\AIM3\Week.10\Week.10.Brent_Oil_Price_Impacts\scripts'
src_dir = r'E:\DS+ML\AIM3\Week.10\Week.10.Brent_Oil_Price_Impacts\src'
file_path = r"E:\DS+ML\AIM3\Week.10\Data\BrentOilPrices.csv"
if scripts_dir not in sys.path:
    sys.path.append(scripts_dir)
if src_dir not in sys.path:
    sys.path.append(src_dir)

# %%
from data_load import load_brent_data
from full_eda_analysis import full_eda_analysis
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.

# %%
df = load_brent_data(file_path)
df.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
full_eda_analysis(df)
# Out:
# Checking for missing values...
#
# No missing values found.
#
# Summary Statistics:
#                                 Date        Price
# count                           8360  8360.000000
# mean   2003-10-31 11:48:17.224880256    46.459669
# min              1987-05-20 00:00:00     9.100000
# 25%              1995-07-31 18:00:00    18.780000
# 50%              2003-10-29 12:00:00    31.750000
# 75%              2012-01-30 06:00:00    67.042500
# max              2020-04-21 00:00:00   143.950000
# std                              NaN    32.504671
#
# Generating visualizations...
#
# No missing values found.
#
# Summary Statistics:
#                                 Date        Price
# count                           8360  8360.000000
# mean   2003-10-31 11:48:17.224880256    46.459669
# min              1987-05-20 00:00:00     9.100000
# 25%              1995-07-31 18:00:00    18.780000
# 50%              2003-10-29 12:00:00    31.750000
# 75%              2012-01-30 06:00:00    67.042500
# max              2020-04-21 00:00:00   143.950000
# std                              NaN    32.504671
# Performing time series decomposition...
# Detecting change points with Pelt...
# Performing CUSUM analysis...
# Detecting Bayesian change point...
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >NUTS: [mu_before, mu_after, sigma]
# >Metropolis: [change_point]
# Output()
